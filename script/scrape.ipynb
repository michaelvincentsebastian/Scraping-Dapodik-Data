# %%
import pandas as pd

# %%
dataframe = pd.read_html('https://dapo.kemendikdasmen.go.id/')

# %%
print(dataframe)
# Out:
# [   No           Tanggal  Jumlah
# 0   1  17 November 2025  17.876
# 1   2  16 November 2025   3.927
# 2   3  15 November 2025   8.427
# 3   4  14 November 2025  13.380
# 4   5  13 November 2025  14.199
# 5   6  12 November 2025  14.117
# 6   7  11 November 2025  12.810
# 7   8  10 November 2025  10.434
# 8   9  09 November 2025   2.903
# 9  10  08 November 2025   5.215]
